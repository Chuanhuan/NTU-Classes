# %%
import numpy as np
def my_bisection(f, x,mu, beta, a, b, tol , max_iterations=1000):
    """
    Approximates a root of the function f within the interval [a, b]
    to within a specified tolerance |f(a+b/2)| < tol.

    Args:
        f: The function for which we want to find the root.
        a, b: Interval endpoints.
        tol: Tolerance (desired accuracy).

    Returns:
        Approximated root.
    """
    # Check if a and b bound a root
    # if f(a) * f(b) >= 0:
    #     raise Exception("The scalars a and b do not bound a root")
    i = 0
    x_k = x

    while np.any(abs((b-a) / 2) >= tol):
        direction = d(x_k,mu)
    # for i in range(max_iterations):
        m = (a + b) / 2  # Midpoint
        x_k = x + m * direction
        output = f(x_k,mu)
        print(f'Iteration {i}: a={a}, b={b}, m={m}, theta_prime(m)={output}, x_k={x_k}, direction={direction}')

        if output > 0:
            b = m 
        else:
            a = m       
        i += 1
        # mu = beta * mu
        if i==max_iterations:
            break
    return (a + b) / 2

mu = 1/2
beta = 2
epsilon = .03
x = [4,2] 
a = -100.0
b = 100.0
# Define the objective function and constraints
def objective_function(x):
  return x[0]**2 + 4*x[1]**2 - 8*x[0] - 16*x[1]

def constraint1(x):
  return x[0] + x[1] - 5

def d(x, mu):
    if max(0,constraint1(x)) >0:
        return -np.array([2*x[0] - 8 + 2*mu*(x[0] + x[1] - 5), 8*x[1] - 16 + 2*mu*(x[0] + x[1] - 5)])
    else:
        return -np.array([2*x[0] - 8, 8*x[1] - 16])

# Define the augmented Lagrangian function
theta = lambda x, l, mu: objective_function(x + l * d(x, mu)) + mu * max(0, constraint1(x + l * d(x, mu))) ** 2
def theta_prime(x,mu):
    if max(0,constraint1(x)) >0:
        return 2*x[0]*d(x,mu)[0] + 8*x[1]*d(x,mu)[1] - 8*d(x,mu)[0]- 16*d(x,mu)[1] + 2*mu*(x[0] + x[1] - 5)*(d(x,mu)[0] + d(x,mu)[1])
    else:
        return 2*x[0]*d(x,mu)[0] + 8*x[1]*d(x,mu)[1] - 8*d(x,mu)[0]- 16*d(x,mu)[1] 

f_prime = lambda x, l, mu: -d(x + l*d(x,mu), mu)

print(d(x,mu))
my_bisection(theta_prime, x,mu, beta, a, b, tol=.00001)
# Out:
# [-1. -1.]
# Iteration 0: a=-100.0, b=100.0, m=0.0, f(m)=-2.0, x_k=[4. 2.], direction=[-1. -1.]
# Iteration 1: a=0.0, b=100.0, m=50.0, f(m)=-170000.0, x_k=[-46. -48.], direction=[-1. -1.]
# Iteration 2: a=50.0, b=100.0, m=75.0, f(m)=-79763160002.0, x_k=[ 7504. 30002.], direction=[100. 400.]
# Iteration 3: a=75.0, b=100.0, m=87.5, f(m)=-3.7817747822395624e+16, x_k=[ -4593833.5 -24281335.5], direction=[ -52501. -277501.]
# Iteration 4: a=87.5, b=100.0, m=93.75, f(m)=-2.7578413950331645e+22, x_k=[8.61344535e+08 1.82110031e+10], direction=[9.187675e+06 1.942507e+08]
# Iteration 5: a=93.75, b=100.0, m=96.875, f(m)=-1.6320787626784606e+28, x_k=[-2.01451918e+12 -1.59611611e+13], direction=[-2.07950367e+10 -1.64760373e+11]
# Iteration 6: a=96.875, b=100.0, m=98.4375, f(m)=-1.3076410807511846e+34, x_k=[3.96608464e+14 1.25694144e+16], direction=[4.02903836e+12 1.27689289e+14]
# Iteration 7: a=98.4375, b=100.0, m=99.21875, f(m)=-8.126827509658809e+39, x_k=[-1.36517457e+18 -1.12634452e+19], direction=[-1.37592398e+16 -1.13521338e+17]
# Iteration 8: a=99.21875, b=100.0, m=99.609375, f(m)=-6.665297773352381e+45, x_k=[2.71968371e+20 8.97555792e+21], direction=[2.73034914e+18 9.01075619e+19]
# Iteration 9: a=99.609375, b=100.0, m=99.8046875, f(m)=-4.1918444365338814e+51, x_k=[-9.77233908e+23 -8.08936850e+24], direction=[-9.79146303e+21 -8.10519896e+22]
# Iteration 10: a=99.8046875, b=100.0, m=99.90234375, f(m)=-3.4581539521987535e+57, x_k=[1.95255916e+26 6.46517498e+27], direction=[1.95446782e+24 6.47149480e+25]
# Iteration 11: a=99.90234375, b=100.0, m=99.951171875, f(m)=-2.1812573581017075e+63, x_k=[-7.04749988e+29 -5.83533240e+30], direction=[-7.05094273e+27 -5.83818307e+28]
# Iteration 12: a=99.951171875, b=100.0, m=99.9755859375, f(m)=-1.802112166465845e+69, x_k=[1.40915586e+32 4.66712620e+33], direction=[1.40949998e+30 4.66826592e+31]
# Iteration 13: a=99.9755859375, b=100.0, m=99.98779296875, f(m)=-1.1375299343443817e+75, x_k=[-5.08925164e+35 -4.21399068e+36], direction=[-5.08987296e+33 -4.21450514e+34]
# Iteration 14: a=99.98779296875, b=100.0, m=99.993896484375, f(m)=-9.401491241098178e+80, x_k=[1.01778820e+38 3.37098678e+39], direction=[1.01785033e+36 3.37119254e+37]
# Iteration 15: a=99.993896484375, b=100.0, m=99.9969482421875, f(m)=-5.935499988113143e+86, x_k=[-3.67621105e+41 -3.04397309e+42], direction=[-3.67632324e+39 -3.04406598e+40]
# Iteration 16: a=99.9969482421875, b=100.0, m=99.99847412109375, f(m)=-4.906038786404439e+92, x_k=[7.35230991e+43 2.43514131e+45], direction=[7.35242210e+41 2.43517847e+43]
# Iteration 17: a=99.99847412109375, b=100.0, m=99.99923706054688, f(m)=-3.0975007656271426e+98, x_k=[-2.65569035e+47 -2.19896271e+48], direction=[-2.65571061e+45 -2.19897949e+46]
# Iteration 18: a=99.99923706054688, b=100.0, m=99.99961853027344, f(m)=-2.5603246128615972e+104, x_k=[5.31136043e+49 1.75916346e+51], direction=[5.31138069e+47 1.75917017e+49]
# Iteration 19: a=99.99961853027344, b=100.0, m=99.99980926513672, f(m)=-1.6165176338177855e+110, x_k=[-1.91850061e+53 -1.58855544e+54], direction=[-1.91850427e+51 -1.58855847e+52]
# Iteration 20: a=99.99980926513672, b=100.0, m=99.99990463256836, f(m)=-1.3361848407548907e+116, x_k=[3.83699757e+55 1.27084314e+57], direction=[3.83700123e+53 1.27084436e+55]
# Iteration 21: a=99.99990463256836, b=100.0, m=99.99995231628418, f(m)=-8.43632298048726e+121, x_k=[-1.38595241e+59 -1.14759528e+60], direction=[-1.38595307e+57 -1.14759583e+58]
# Iteration 22: a=99.99995231628418, b=100.0, m=99.99997615814209, f(m)=-6.973325108115944e+127, x_k=[2.77190416e+61 9.18076005e+62], direction=[2.77190482e+59 9.18076224e+60]
# Iteration 23: a=99.99997615814209, b=100.0, m=99.99998807907104, f(m)=-4.4027789527117413e+133, x_k=[-1.00123301e+65 -8.29040210e+65], direction=[-1.00123313e+63 -8.29040308e+63]
# 99.99999403953552

# %%
import numpy as np
def my_bisection(f_prime, mu, beta, a, b, tol , max_iterations=1000):
    """
    Approximates a root of the function f within the interval [a, b]
    to within a specified tolerance |f(a+b/2)| < tol.

    Args:
        f: The function for which we want to find the root.
        a, b: Interval endpoints.
        tol: Tolerance (desired accuracy).

    Returns:
        Approximated root.
    """
    # Check if a and b bound a root
    # if f(a) * f(b) >= 0:
    #     raise Exception("The scalars a and b do not bound a root")
    i = 0
    while np.any(abs((b-a) / 2) >= tol):
    # for i in range(max_iterations):
        m = (a + b) / 2  # Midpoint
        print(f'Iteration {i}: a={a}, b={b}, m={m}, f_prime(m)={f_prime(m,mu)}')
        result = [i>0 for i in f_prime(m,mu)]

        if result[0] :
            b[0] = m[0]  
        else:
            a[0] = m[0] 
        if result[1] :
            b[1] = m[1]  
        else:
            a[1] = m[1]              
        
        i += 1
        mu = beta * mu
        
        if i==max_iterations:
            break
    return (a + b) / 2

mu = 1/2
beta = 2
epsilon = .03
x = [4,2] 
a = np.array([-100.0,-100.0])
b = np.array([100.0,100.0])
# Define the objective function and constraints
def objective_function(x):
  return x[0]**2 + 4*x[1]**2 - 8*x[0] - 16*x[1]

def constraint1(x):
  return x[0] + x[1] - 5

def func(x, mu ):
    return objective_function(x) + mu*max(0,constraint1(x))**2

def d(x, mu):
    if max(0,constraint1(x)) >0:
        return np.array([2*x[0] - 8 + 2*mu*(x[0] + x[1] - 5), 8*x[1] - 16 + 2*mu*(x[0] + x[1] - 5)])
    else:
        return np.array([2*x[0] - 8, 8*x[1] - 16])

print(d(x,mu))
m = my_bisection(f_prime= d, mu = mu, beta = beta, a =a, b=b, tol = epsilon , max_iterations=100)
print(f'x1: {m[0]}, x2: {m[1]}, the objective function: {objective_function(m)}')
# Out:
# [1. 1.]
# Iteration 0: a=[-100. -100.], b=[100. 100.], m=[0. 0.], f_prime(m)=[ -8. -16.]
# Iteration 1: a=[0. 0.], b=[100. 100.], m=[50. 50.], f_prime(m)=[282. 574.]
# Iteration 2: a=[0. 0.], b=[50. 50.], m=[25. 25.], f_prime(m)=[222. 364.]
# Iteration 3: a=[0. 0.], b=[25. 25.], m=[12.5 12.5], f_prime(m)=[177. 244.]
# Iteration 4: a=[0. 0.], b=[12.5 12.5], m=[6.25 6.25], f_prime(m)=[124.5 154. ]
# Iteration 5: a=[0. 0.], b=[6.25 6.25], m=[3.125 3.125], f_prime(m)=[38.25 49.  ]
# Iteration 6: a=[0. 0.], b=[3.125 3.125], m=[1.5625 1.5625], f_prime(m)=[-4.875 -3.5  ]
# Iteration 7: a=[1.5625 1.5625], b=[3.125 3.125], m=[2.34375 2.34375], f_prime(m)=[-3.3125  2.75  ]
# Iteration 8: a=[2.34375 1.5625 ], b=[3.125   2.34375], m=[2.734375 1.953125], f_prime(m)=[-2.53125 -0.375  ]
# Iteration 9: a=[2.734375 1.953125], b=[3.125   2.34375], m=[2.9296875 2.1484375], f_prime(m)=[37.859375 41.1875  ]
# Iteration 10: a=[2.734375 1.953125], b=[2.9296875 2.1484375], m=[2.83203125 2.05078125], f_prime(m)=[-2.3359375  0.40625  ]
# Iteration 11: a=[2.83203125 1.953125  ], b=[2.9296875  2.05078125], m=[2.88085938 2.00195312], f_prime(m)=[-2.23828125  0.015625  ]
# x1: 2.9052734375, x2: 1.9775390625, the objective function: -30.799555778503418

# %%
def objective_function(x):
    # Define your objective function here
    return x[0]**2 + 4*x[1]**2 - 8*x[0] - 16*x[1]

def constraint_function(x):
    # Define your constraint function here
    return x[0] + x[1] - 5

def barrier_function(x, mu):
    # Calculate the penalty term
    penalty = -1/constraint_function(x)

    # Calculate the barrier function as the sum of the objective function and the penalty term
    return objective_function(x) + mu * penalty

def d(x, mu):
    return np.array([2*x[0] - 8 + mu*(x[0] + x[1] - 5)**(-2), 8*x[1] - 16+ mu*(x[0] + x[1] - 5)**(-2)])

mu = 8
beta = .5
epsilon = .06
x = [4,2] 
a = np.array([-100.0,-100.0])
b = np.array([100.0,100.0])
m = my_bisection(f_prime= d, mu = mu, beta = beta, a =a, b=b, tol = epsilon , max_iterations=100)
print(f'x1: {m[0]}, x2: {m[1]}, the objective function: {objective_function(m)}')
# Out:
# Iteration 0: a=[-100. -100.], b=[100. 100.], m=[0. 0.], f_prime(m)=[ -7.68 -15.68]
# Iteration 1: a=[0. 0.], b=[100. 100.], m=[50. 50.], f_prime(m)=[ 92.00044321 384.00044321]
# Iteration 2: a=[0. 0.], b=[50. 50.], m=[25. 25.], f_prime(m)=[ 42.00098765 184.00098765]
# Iteration 3: a=[0. 0.], b=[25. 25.], m=[12.5 12.5], f_prime(m)=[17.0025 84.0025]
# Iteration 4: a=[0. 0.], b=[12.5 12.5], m=[6.25 6.25], f_prime(m)=[ 4.50888889 34.00888889]
# Iteration 5: a=[0. 0.], b=[6.25 6.25], m=[3.125 3.125], f_prime(m)=[-1.59  9.16]
# Iteration 6: a=[3.125 0.   ], b=[6.25  3.125], m=[4.6875 1.5625], f_prime(m)=[ 1.455 -3.42 ]
# Iteration 7: a=[3.125  1.5625], b=[4.6875 3.125 ], m=[3.90625 2.34375], f_prime(m)=[-0.1475  2.79  ]
# Iteration 8: a=[3.90625 1.5625 ], b=[4.6875  2.34375], m=[4.296875 1.953125], f_prime(m)=[ 0.61375 -0.355  ]
# Iteration 9: a=[3.90625  1.953125], b=[4.296875 2.34375 ], m=[4.1015625 2.1484375], f_prime(m)=[0.213125 1.1975  ]
# Iteration 10: a=[3.90625  1.953125], b=[4.1015625 2.1484375], m=[4.00390625 2.05078125], f_prime(m)=[0.01483582 0.41327332]
# x1: 3.955078125, x2: 2.001953125, the objective function: -31.997966766357422

# %%
import numpy as np

def penalty_function(x, f, constraints, penalty_param):
  """
  Calculates the penalty function value.

  Args:
    x: The decision variable vector.
    f: The objective function.
    constraints: A list of constraint functions.
    penalty_param: The penalty parameter.

  Returns:
    The penalty function value.
  """
  penalty = 0
  for constraint in constraints:
    violation = max(0, constraint(x))
    penalty += penalty_param * violation**2
  return f(x) + penalty

# Define the objective function and constraints
def objective_function(x):
  return x[0]**2 + 4*x[1]**2 - 8*x[0] - 16*x[1]

def constraint1(x):
  return x[0] + x[1] - 5

def constraint2(x):
  return x[0] - 3

# Set the initial guess, penalty parameter, and tolerance
x0 = np.array([4, 2])
penalty_param = 1000
tolerance = .03

# Use an unconstrained optimization algorithm to minimize the penalty function
from scipy.optimize import minimize
result = minimize(penalty_function, x0, args=(objective_function, [constraint1, constraint2], penalty_param))

# Print the solution
print(f"Optimal solution: {result.x}")
print(f"Objective function value: {objective_function(result.x)}")
# Out:
# Optimal solution: [3.00099503 1.99900892]
# Objective function value: -31.00198514750079
