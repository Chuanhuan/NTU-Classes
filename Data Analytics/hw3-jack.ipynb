# %% [markdown]
# <h1><center>Data Analytics</h1>
# <h2><center>Homework 3</h2>
# <h3><center>Name: 李權桓   &emsp;   ID:10546004</h3>

# %% [markdown]
# # q5

# %%
# importing pandas
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
# Read Text Files with Pandas

col_names = ['mpg','cylinders','displacement','horsepower',
            'weight','acceleration','year','origin','car_name']
# read text file into pandas DataFrame
df = pd.read_fwf("auto-mpg.data.txt",header=None,names = col_names)
# df = pd.DataFrame(df1.to_numpy() , columns=col_names)
# display DataFrame
print(df)
corr = df.corr()
# plot the heatmap

cmap = cmap=sns.diverging_palette(6, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "14pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "20pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '400px'),
                        ('font-size', '20pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Car data correlation matrix")\
    .format(precision=2)\
    .set_table_styles(magnify()).set_table_styles(magnify())
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0      130.0  3504.0          12.0    70
# 1    15.0          8         350.0      165.0  3693.0          11.5    70
# 2    18.0          8         318.0      150.0  3436.0          11.0    70
# 3    16.0          8         304.0      150.0  3433.0          12.0    70
# 4    17.0          8         302.0      140.0  3449.0          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 393  27.0          4         140.0      86.00  2790.0          15.6    82
# 394  44.0          4          97.0      52.00  2130.0          24.6    82
# 395  32.0          4         135.0      84.00  2295.0          11.6    82
# 396  28.0          4         120.0      79.00  2625.0          18.6    82
# 397  31.0          4         119.0      82.00  2720.0          19.4    82
#
#      origin                     car_name
# 0         1  "chevrolet chevelle malibu"
# 1         1          "buick skylark 320"
# 2         1         "plymouth satellite"
# 3         1              "amc rebel sst"
# 4         1                "ford torino"
# ..      ...                          ...
# 393       1            "ford mustang gl"
# 394       2                  "vw pickup"
# 395       1              "dodge rampage"
# 396       1                "ford ranger"
# 397       1                 "chevy s-10"
#
# [398 rows x 9 columns]
# <style type="text/css">
# #T_c8cde th {
#   font-size: 14pt;
# }
# #T_c8cde td {
#   padding: 0em 0em;
# }
# #T_c8cde th:hover {
#   font-size: 20pt;
# }
# #T_c8cde tr:hover td:hover {
#   max-width: 400px;
#   font-size: 20pt;
# }
# #T_c8cde_row0_col0, #T_c8cde_row1_col1, #T_c8cde_row2_col2, #T_c8cde_row3_col3, #T_c8cde_row4_col4, #T_c8cde_row5_col5, #T_c8cde_row6_col6 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row0_col1, #T_c8cde_row6_col1 {
#   background-color: #d94560;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row0_col2 {
#   background-color: #d8405b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row0_col3, #T_c8cde_row1_col0, #T_c8cde_row2_col0, #T_c8cde_row3_col0, #T_c8cde_row4_col2, #T_c8cde_row5_col2, #T_c8cde_row6_col2 {
#   background-color: #d83b57;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row0_col4 {
#   background-color: #b2c6de;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row0_col5 {
#   background-color: #92b0d4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row0_col6 {
#   background-color: #96b2d5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row1_col2 {
#   background-color: #4d7fbe;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row1_col3, #T_c8cde_row3_col1 {
#   background-color: #5786c1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row1_col4 {
#   background-color: #e07185;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row1_col5, #T_c8cde_row2_col5 {
#   background-color: #e492a1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row1_col6 {
#   background-color: #de667b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row2_col1 {
#   background-color: #4c7ebd;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row2_col3, #T_c8cde_row3_col2 {
#   background-color: #5081bf;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row2_col4 {
#   background-color: #df6f83;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row2_col6 {
#   background-color: #dd6278;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row3_col4 {
#   background-color: #e48d9c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row3_col5 {
#   background-color: #e7a4b0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row3_col6 {
#   background-color: #df6d81;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row4_col0 {
#   background-color: #c7d4e5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row4_col1 {
#   background-color: #d9445f;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row4_col3 {
#   background-color: #dc586f;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row4_col5 {
#   background-color: #e4e9ee;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row4_col6 {
#   background-color: #f2eded;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row5_col0 {
#   background-color: #aec3dd;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row5_col1, #T_c8cde_row6_col3 {
#   background-color: #d9415c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row5_col3 {
#   background-color: #da4b65;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row5_col4 {
#   background-color: #f1eaeb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row5_col6 {
#   background-color: #edcdd3;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row6_col0 {
#   background-color: #a2bad9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row6_col4 {
#   background-color: #eff0f2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_c8cde_row6_col5 {
#   background-color: #f2eeee;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# </style>
# <table id="T_c8cde">
#   <caption>Car data correlation matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8cde_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_c8cde_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_c8cde_level0_col2" class="col_heading level0 col2" >displacement</th>
#       <th id="T_c8cde_level0_col3" class="col_heading level0 col3" >weight</th>
#       <th id="T_c8cde_level0_col4" class="col_heading level0 col4" >acceleration</th>
#       <th id="T_c8cde_level0_col5" class="col_heading level0 col5" >year</th>
#       <th id="T_c8cde_level0_col6" class="col_heading level0 col6" >origin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8cde_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_c8cde_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_c8cde_row0_col1" class="data row0 col1" >-0.78</td>
#       <td id="T_c8cde_row0_col2" class="data row0 col2" >-0.80</td>
#       <td id="T_c8cde_row0_col3" class="data row0 col3" >-0.83</td>
#       <td id="T_c8cde_row0_col4" class="data row0 col4" >0.42</td>
#       <td id="T_c8cde_row0_col5" class="data row0 col5" >0.58</td>
#       <td id="T_c8cde_row0_col6" class="data row0 col6" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_c8cde_level0_row1" class="row_heading level0 row1" >cylinders</th>
#       <td id="T_c8cde_row1_col0" class="data row1 col0" >-0.78</td>
#       <td id="T_c8cde_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_c8cde_row1_col2" class="data row1 col2" >0.95</td>
#       <td id="T_c8cde_row1_col3" class="data row1 col3" >0.90</td>
#       <td id="T_c8cde_row1_col4" class="data row1 col4" >-0.51</td>
#       <td id="T_c8cde_row1_col5" class="data row1 col5" >-0.35</td>
#       <td id="T_c8cde_row1_col6" class="data row1 col6" >-0.56</td>
#     </tr>
#     <tr>
#       <th id="T_c8cde_level0_row2" class="row_heading level0 row2" >displacement</th>
#       <td id="T_c8cde_row2_col0" class="data row2 col0" >-0.80</td>
#       <td id="T_c8cde_row2_col1" class="data row2 col1" >0.95</td>
#       <td id="T_c8cde_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_c8cde_row2_col3" class="data row2 col3" >0.93</td>
#       <td id="T_c8cde_row2_col4" class="data row2 col4" >-0.54</td>
#       <td id="T_c8cde_row2_col5" class="data row2 col5" >-0.37</td>
#       <td id="T_c8cde_row2_col6" class="data row2 col6" >-0.61</td>
#     </tr>
#     <tr>
#       <th id="T_c8cde_level0_row3" class="row_heading level0 row3" >weight</th>
#       <td id="T_c8cde_row3_col0" class="data row3 col0" >-0.83</td>
#       <td id="T_c8cde_row3_col1" class="data row3 col1" >0.90</td>
#       <td id="T_c8cde_row3_col2" class="data row3 col2" >0.93</td>
#       <td id="T_c8cde_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_c8cde_row3_col4" class="data row3 col4" >-0.42</td>
#       <td id="T_c8cde_row3_col5" class="data row3 col5" >-0.31</td>
#       <td id="T_c8cde_row3_col6" class="data row3 col6" >-0.58</td>
#     </tr>
#     <tr>
#       <th id="T_c8cde_level0_row4" class="row_heading level0 row4" >acceleration</th>
#       <td id="T_c8cde_row4_col0" class="data row4 col0" >0.42</td>
#       <td id="T_c8cde_row4_col1" class="data row4 col1" >-0.51</td>
#       <td id="T_c8cde_row4_col2" class="data row4 col2" >-0.54</td>
#       <td id="T_c8cde_row4_col3" class="data row4 col3" >-0.42</td>
#       <td id="T_c8cde_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_c8cde_row4_col5" class="data row4 col5" >0.29</td>
#       <td id="T_c8cde_row4_col6" class="data row4 col6" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_c8cde_level0_row5" class="row_heading level0 row5" >year</th>
#       <td id="T_c8cde_row5_col0" class="data row5 col0" >0.58</td>
#       <td id="T_c8cde_row5_col1" class="data row5 col1" >-0.35</td>
#       <td id="T_c8cde_row5_col2" class="data row5 col2" >-0.37</td>
#       <td id="T_c8cde_row5_col3" class="data row5 col3" >-0.31</td>
#       <td id="T_c8cde_row5_

# %%
# find to missing value
df[df.isin({'?'}).any(1)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0          ?  2046.0          19.0    71
# 126  21.0          6         200.0          ?  2875.0          17.0    74
# 330  40.9          4          85.0          ?  1835.0          17.3    80
# 336  23.6          4         140.0          ?  2905.0          14.3    80
# 354  34.5          4         100.0          ?  2320.0          15.8    81
# 374  23.0          4         151.0          ?  3035.0          20.5    82
#
#      origin                car_name
# 32        1            "ford pinto"
# 126       1         "ford maverick"
# 330       2  "renault lecar deluxe"
# 336       1    "ford mustang cobra"
# 354       2           "renault 18i"
# 374       1        "amc concord dl"

# %% [markdown]
# There are 6 missing horsepower values. After cleanning data, the result looks identical to lecture slides.

# %%
df = df[~df.isin({'?'}).any(1)]
corr = df.corr()
print('Check the data dimention is ', df.shape)
corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Car data correlation matrix")\
    .format(precision=2)\
    .set_table_styles(magnify()).set_table_styles(magnify())
# Out:
# Check the data dimention is  (392, 9)
# <style type="text/css">
# #T_9666a th {
#   font-size: 14pt;
# }
# #T_9666a td {
#   padding: 0em 0em;
# }
# #T_9666a th:hover {
#   font-size: 20pt;
# }
# #T_9666a tr:hover td:hover {
#   max-width: 400px;
#   font-size: 20pt;
# }
# #T_9666a_row0_col0, #T_9666a_row1_col1, #T_9666a_row2_col2, #T_9666a_row3_col3, #T_9666a_row4_col4, #T_9666a_row5_col5, #T_9666a_row6_col6 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row0_col1, #T_9666a_row6_col1 {
#   background-color: #d94560;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row0_col2 {
#   background-color: #d8405b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row0_col3, #T_9666a_row1_col0, #T_9666a_row2_col0, #T_9666a_row3_col0, #T_9666a_row4_col2, #T_9666a_row5_col2, #T_9666a_row6_col2 {
#   background-color: #d83b57;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row0_col4 {
#   background-color: #b1c5de;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row0_col5 {
#   background-color: #92b0d4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row0_col6 {
#   background-color: #95b1d5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row1_col2 {
#   background-color: #4d7fbe;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row1_col3, #T_9666a_row3_col1 {
#   background-color: #5786c1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row1_col4 {
#   background-color: #e07386;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row1_col5 {
#   background-color: #e594a2;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row1_col6 {
#   background-color: #de667b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row2_col1 {
#   background-color: #4c7ebd;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row2_col3, #T_9666a_row3_col2 {
#   background-color: #5081bf;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row2_col4 {
#   background-color: #df7084;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row2_col5 {
#   background-color: #e492a1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row2_col6 {
#   background-color: #dd6278;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row3_col4 {
#   background-color: #e48e9d;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row3_col5 {
#   background-color: #e7a4b0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row3_col6 {
#   background-color: #df6c80;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row4_col0 {
#   background-color: #c5d3e4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row4_col1 {
#   background-color: #d9445f;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row4_col3 {
#   background-color: #dc5971;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row4_col5 {
#   background-color: #e3e8ee;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row4_col6 {
#   background-color: #f2eeee;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row5_col0 {
#   background-color: #aec3dd;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row5_col1, #T_9666a_row6_col3 {
#   background-color: #d9415c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row5_col3 {
#   background-color: #da4b65;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row5_col4 {
#   background-color: #f2ebec;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row5_col6 {
#   background-color: #edcfd4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row6_col0 {
#   background-color: #a1b9d9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row6_col4 {
#   background-color: #edeef1;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_9666a_row6_col5 {
#   background-color: #f2eff0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# </style>
# <table id="T_9666a">
#   <caption>Car data correlation matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9666a_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_9666a_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_9666a_level0_col2" class="col_heading level0 col2" >displacement</th>
#       <th id="T_9666a_level0_col3" class="col_heading level0 col3" >weight</th>
#       <th id="T_9666a_level0_col4" class="col_heading level0 col4" >acceleration</th>
#       <th id="T_9666a_level0_col5" class="col_heading level0 col5" >year</th>
#       <th id="T_9666a_level0_col6" class="col_heading level0 col6" >origin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9666a_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_9666a_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_9666a_row0_col1" class="data row0 col1" >-0.78</td>
#       <td id="T_9666a_row0_col2" class="data row0 col2" >-0.81</td>
#       <td id="T_9666a_row0_col3" class="data row0 col3" >-0.83</td>
#       <td id="T_9666a_row0_col4" class="data row0 col4" >0.42</td>
#       <td id="T_9666a_row0_col5" class="data row0 col5" >0.58</td>
#       <td id="T_9666a_row0_col6" class="data row0 col6" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_9666a_level0_row1" class="row_heading level0 row1" >cylinders</th>
#       <td id="T_9666a_row1_col0" class="data row1 col0" >-0.78</td>
#       <td id="T_9666a_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_9666a_row1_col2" class="data row1 col2" >0.95</td>
#       <td id="T_9666a_row1_col3" class="data row1 col3" >0.90</td>
#       <td id="T_9666a_row1_col4" class="data row1 col4" >-0.50</td>
#       <td id="T_9666a_row1_col5" class="data row1 col5" >-0.35</td>
#       <td id="T_9666a_row1_col6" class="data row1 col6" >-0.57</td>
#     </tr>
#     <tr>
#       <th id="T_9666a_level0_row2" class="row_heading level0 row2" >displacement</th>
#       <td id="T_9666a_row2_col0" class="data row2 col0" >-0.81</td>
#       <td id="T_9666a_row2_col1" class="data row2 col1" >0.95</td>
#       <td id="T_9666a_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_9666a_row2_col3" class="data row2 col3" >0.93</td>
#       <td id="T_9666a_row2_col4" class="data row2 col4" >-0.54</td>
#       <td id="T_9666a_row2_col5" class="data row2 col5" >-0.37</td>
#       <td id="T_9666a_row2_col6" class="data row2 col6" >-0.61</td>
#     </tr>
#     <tr>
#       <th id="T_9666a_level0_row3" class="row_heading level0 row3" >weight</th>
#       <td id="T_9666a_row3_col0" class="data row3 col0" >-0.83</td>
#       <td id="T_9666a_row3_col1" class="data row3 col1" >0.90</td>
#       <td id="T_9666a_row3_col2" class="data row3 col2" >0.93</td>
#       <td id="T_9666a_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_9666a_row3_col4" class="data row3 col4" >-0.42</td>
#       <td id="T_9666a_row3_col5" class="data row3 col5" >-0.31</td>
#       <td id="T_9666a_row3_col6" class="data row3 col6" >-0.59</td>
#     </tr>
#     <tr>
#       <th id="T_9666a_level0_row4" class="row_heading level0 row4" >acceleration</th>
#       <td id="T_9666a_row4_col0" class="data row4 col0" >0.42</td>
#       <td id="T_9666a_row4_col1" class="data row4 col1" >-0.50</td>
#       <td id="T_9666a_row4_col2" class="data row4 col2" >-0.54</td>
#       <td id="T_9666a_row4_col3" class="data row4 col3" >-0.42</td>
#       <td id="T_9666a_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_9666a_row4_col5" class="data row4 col5" >0.29</td>
#       <td id="T_9666a_row4_col6" class="data row4 col6" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_9666a_level0_row5" class="row_heading level0 row5" >year</th>
#       <td id="T_9666a_row5_col0" class="data row5 col0" >0.58</td>
#       <td id="T_9666a_row5_col1" class="data row5 col1" >-0.35</td>
#       <td id="T_9666a_row5_col2" class="data row5 col2" >-0.37</td>
#       <

# %%
col_x = df.columns[1:-1]
for i in col_x:
    print(i)
    y = df[i]
    temp = lambda a,l:[True if x == a else False for x in l]
     x = df[temp]
# Out:
# cylinders
# displacement
# horsepower
# weight
# acceleration
# year
# origin

# %%
df[[]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/jack/Document/NTU-NPS/Data Analytics/hw3-jack.ipynb Cell 10' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/jack/Document/NTU-NPS/Data%20Analytics/hw3-jack.ipynb#ch0000010?line=0'>1</a> df[[True,False]]
#
# File /usr/lib/python3.10/site-packages/pandas/core/frame.py:3496, in DataFrame.__getitem__(self, key)
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3493'>3494</a> # Do we have a (boolean) 1d indexer?
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3494'>3495</a> if com.is_bool_indexer(key):
# -> <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3495'>3496</a>     return self._getitem_bool_array(key)
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3497'>3498</a> # We are left with two options: a single key, and a collection of keys,
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3498'>3499</a> # We interpret tuples as collections only for non-MultiIndex
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3499'>3500</a> is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File /usr/lib/python3.10/site-packages/pandas/core/frame.py:3543, in DataFrame._getitem_bool_array(self, key)
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3536'>3537</a>     warnings.warn(
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3537'>3538</a>         "Boolean Series key will be reindexed to match DataFrame index.",
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3538'>3539</a>         UserWarning,
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3539'>3540</a>         stacklevel=find_stack_level(),
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3540'>3541</a>     )
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3541'>3542</a> elif len(key) != len(self.index):
# -> <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3542'>3543</a>     raise ValueError(
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3543'>3544</a>         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3544'>3545</a>     )
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3546'>3547</a> # check_bool_indexer will throw exception if Series key cannot
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3547'>3548</a> # be reindexed to match DataFrame rows
#    <a href='file:///usr/lib/python3.10/site-packages/pandas/core/frame.py?line=3548'>3549</a> key = check_bool_indexer(self.index, key)
#
# ValueError: Item wrong length 2 instead of 392.

# %%
model = LinearRegression().fit(data_mat,sample_df['gender'])
r_sq = model.score(data_mat, sample_df['gender'])
print('R-square: ', r_sq)
print('beta_0 :', model.intercept_)
print('All other betas: ', model.coef_)
